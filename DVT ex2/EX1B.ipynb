# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\SHREYA\Downloads\Sleep_health_and_lifestyle_dataset.csv")
print(df.head())
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# DATA UNDERSTANDING
print("Dataset Shape:")
print(df.shape)
print("\nDataset Information:")
print(df.info())
print("\nStatistical Summary:")
print(df.describe())
print("\nMissing Values:")
print(df.isnull().sum())
print("\nDuplicate Records:")
print(df.duplicated().sum())
# Out:
# Dataset Shape:
# (374, 13)
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    str
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    str
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    str
#  9   Blood Pressure           374 non-null    str
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    str
# dtypes: float64(1), int64(7), str(5)
# ...

# %%
df.drop_duplicates(inplace=True)
df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None')
print("Data preparation completed successfully.")
print("\nMissing Values After Cleaning:")
print(df.isnull().sum())
# Out:
# Data preparation completed successfully.
#
# Missing Values After Cleaning:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
# 5. EVALUATION
print("Business insights generated successfully.")
# Out:
# Business insights generated successfully.

# %%
# 6. DEPLOYMENT
print("Insights can be deployed through dashboards.")
# Out:
# Insights can be deployed through dashboards.

# %%
# SEMMA FRAMEWORK
# ============================================================
# SAMPLE
df = pd.read_csv(r"C:\Users\SHREYA\Downloads\Sleep_health_and_lifestyle_dataset.csv")

# %%
# EXPLORE
print(df.head())
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
# MODIFY
df.drop_duplicates(inplace=True)
df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None')

# %%
# MODEL
print("EDA patterns and trends identified successfully.")
# Out:
# EDA patterns and trends identified successfully.

# %%
# ASSESS
print("Patterns and trends successfully identified.")
# Out:
# Patterns and trends successfully identified.

# %%
# KDD FRAMEWORK
# ============================================================
# SELECTION
df = pd.read_csv(r"C:\Users\SHREYA\Downloads\Sleep_health_and_lifestyle_dataset.csv")

# %%
# PREPROCESSING
print(df.info())
print(df.isnull().sum())
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    str
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    str
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    str
#  9   Blood Pressure           374 non-null    str
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    str
# dtypes: float64(1), int64(7), str(5)
# memory usage: 38.1 KB
# None
# ...

# %%
# TRANSFORMATION
df['Sleep Duration'] = pd.to_numeric(df['Sleep Duration'], errors='coerce')

# %%
# DATA MINING
print("Data mining completed successfully.")
# Out:
# Data mining completed successfully.

# %%
# INTERPRETATION
print("Knowledge discovered from the dataset has been interpreted to support sleep health decisions.")
# Out:
# Knowledge discovered from the dataset has been interpreted to support sleep health decisions.

# %%
df['Gender'].value_counts().plot(kind='bar')
plt.title("Gender")
plt.show()
df['Sleep Disorder'].value_counts().plot(kind='bar')
plt.title("Sleep Disorder")
plt.show()
df['Occupation'].value_counts().plot(kind='bar')
plt.title("Occupation")
plt.show()
df['BMI Category'].value_counts().plot(kind='bar')
plt.title("BMI Category")
plt.show()
corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(10,8))
plt.imshow(corr)
plt.colorbar()
plt.xticks(
    range(len(corr.columns)),
    corr.columns,
    rotation=90
)
plt.yticks(
    range(len(corr.columns)),
    corr.columns
)
plt.title("Correlation Heatmap")
plt.show()
